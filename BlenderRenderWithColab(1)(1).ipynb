# %%
#Download Blender from Repository - Run Once unless version changed

# !wget https://ftp.halifax.rwth-aachen.de/blender/release/Blender4.2/blender-4.2.9-linux-x64.tar.xz

# %%
#install Blender
# !tar xf /content/blender-4.2.9-linux-x64.tar.xz

# %%
#Connect Google Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
#set the paths to Blender Files
filename = "/content/drive/MyDrive/des.blend"

# %%
#Render
# !./blender-4.2.9-linux-x64/blender -b $filename -noaudio -E 'CYCLES' -o '/content/drive/MyDrive/'  -s 81 -e 100 -a -F 'PNG' -- --cycles-device CUDA
